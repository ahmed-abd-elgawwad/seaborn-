# %% [markdown]
# # <span style="color:red"> seaborn </span>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set() 
# %matplotlib inline
sns.despine()
sns.set_style("whitegrid")

# %% [markdown]
# ## sns.scatterplot()

# %% [markdown]
# ## sns.countplot()

# %% [markdown]
# ### read data from text file

# %%
# import pandas as pd
# df= pd.read_csv("../data/seeds_dataset (1).txt",sep="\t")

# %% [markdown]
# ## in seaborn the <span style="color:red">hue </span>arrgument means -> make subgroup in what basis

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure()
sns.set()
sns.scatterplot(x="tip",y="total_bill",hue="smoker",data=tips,hue_order=["Yes","No"],palette={"Yes":"red","No":"black"})
sns.despine()
plt.show()

# %%
plt.figure()
sns.set()
sns.regplot(x="tip",y="total_bill",data=tips,fit_reg=True)
sns.despine()
plt.show()

# %%
plt.figure()
sns.countplot(y="smoker",data=tips)
sns.despine()
plt.show()

# %%
# %matplotlib notebook
plt.figure()
sns.barplot(x="day",y="total_bill",data=tips,palette="Blues_d",hue="sex")
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
tips.groupby(["day","sex"]).total_bill.mean()
# Out:
# day   sex
# Thur  Male      18.714667
#       Female    16.715312
# Fri   Male      19.857000
#       Female    14.145556
# Sat   Male      20.802542
#       Female    19.680357
# Sun   Male      21.887241
#       Female    19.872222
# Name: total_bill, dtype: float64

# %%
plt.figure()
sns.countplot(x="day",data=tips,palette="Blues_d",hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
plt.figure()
sns.countplot(y="smoker",hue="sex",data=tips)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tips.groupby(["smoker","sex"]).smoker.value_counts()
# Out:
# smoker  sex     smoker
# Yes     Male    Yes       60
#         Female  Yes       33
# No      Male    No        97
#         Female  No        54
# Name: smoker, dtype: int64

# %% [markdown]
# # <span style="color:blue">seaborn totourial</span>

# %% [markdown]
# ## styling the plot

# %% [markdown]
# ### sns.set_style(  grid_type , axis_Style )
# #### 1- grid_type -> dark / white / darkgrid / whitegrid / ticks
# #### 2- axis_style -> sommon use  {'axes.axisbelow': False / True}  to make the axis and grid below or above the schtech

# %%
plt.figure()
sns.set_style("darkgrid")
sns.countplot(y="sex", data=tips)
sns.despine()
plt.ylabel("sex",fontsize=15)
plt.yticks(fontsize=6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # displot()
# ### displot( data= the_series , bins= num , hist=Ture , kde=False )
# ### kde -> propaility denisty function

# %%
iris=sns.load_dataset("iris")

# %%
plt.figure()
plt.hist(iris['petal_length'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.displot(iris['petal_length'],bins=10,kde=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# # jointplot( x= variable-1 , y=variable-2 , data= df )
# ### used to show the relation between two variables and the distribution of each variables also

# %%
plt.figure()
sns.jointplot(x="petal_length",y="petal_width",data=iris)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### from the above , the two variables has a positive correration

# %%
plt.figure()
sns.jointplot(x="petal_length",y="petal_width",data=iris,kind="hex")
sns.set_style("whitegrid")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="600">

# %%
plt.figure()
sns.jointplot(x="petal_length",y="petal_width",data=iris,kind="kde",color="blue",shade=True)
plt.show()

# %% [markdown]
# ## jointplot() give the relation between two variables and the distribution of each variables
# ## but what if we want to make relation bwteen all variables in the dataframe and also the distribution of each variables in it?

# %% [markdown]
# # pairplot ()

# %% [markdown]
# ## paiplot(df , hue='col_name' , diag_kind="kde/ hist", kind="scatter", palette=" colors" )

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.figure()
sns.pairplot(iris,hue="species",kind="scatter",diag_kind="hist",palette="husl")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1120">

# %%
plt.figure()
sns.pairplot(iris,hue="species",kind="scatter",diag_kind="kde",palette="husl")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1120">

# %% [markdown]
# ### what if not all data columns can be ploted
# ### x_vars , y_vars

# %%
plt.figure()
sns.pairplot(x_vars=["sepal_length","sepal_width","petal_length"],y_vars=["petal_width"]
             ,data=iris,kind="scatter",hue="species",size=3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="1272">

# %% [markdown]
# # nested plot

# %%
import pandas as pd 
import numpy as np

# %%
X=np.arange(1,20,2)
Y= [i**2 for i in X]

# %%
fig=plt.figure(figsize=(10,6))
fig1=fig.add_axes([.1,.1,.8,.8])
fig2=fig.add_axes([.2,.5,.3,.2])
fig1.plot(X,Y,c="red",marker="+")
fig1.set_xlabel(" x ",fontsize=20,color="green")
fig1.set_ylabel(" y ",fontsize=20,color="green",rotation=0)
fig2.plot(X,Y,c="black",marker="o")
fig2.set_ylabel(" y ",fontsize=15,color="green",rotation=0)
fig2.set_xlabel(" x ",fontsize=15,color="green")
plt.show()

# %%
plt.figure()
sns.lineplot(x=X,y=Y,palette="red")
sns.lineplot(x=Y,y=X)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # subplot using seaborn

# %%
fig=plt.figure(figsize=(10,5))
fig1=fig.add_axes([.1,.1,.8,.8])
fig2=fig.add_axes([.2,.5,.3,.2])
fig1.plot(X,Y,c="red")
fig2.plot(X,Y,c="black")
plt.show()

# %%
fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(8,8))
fig.suptitle("Suptitle")
sns.lineplot(x=X,y=Y,ax=axes[0,0])
axes[0,0].set_title("fuck")
sns.lineplot(x=X,y=Y,ax=axes[0,1])
axes[0,1].set_title("fuck")
sns.lineplot(x=X,y=Y,ax=axes[1,0])
axes[1,0].set_title("fuck")
sns.lineplot(x=X,y=Y,ax=axes[1,1])
axes[1,1].set_title("fuck")
# Out:
# Text(0.5, 1.0, 'fuck')

# %% [markdown]
# # lmplot() same as reg plot put in involves hue

# %%
df=sns.load_dataset("iris")
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.figure()
sns.regplot(x="sepal_length",y="sepal_width",data=df)
plt.show()

# %%
plt.figure()
sns.lmplot(x="sepal_length",y="sepal_width",data=df,hue="species")
plt.show()

# %%
plt.figure()
sns.lmplot(x="sepal_length",y="sepal_width",data=df,col="species")
plt.show()

# %%
plt.figure()
sns.boxplot(df["sepal_length"],color="green")
plt.show()
# Out:
# c:\users\ae504\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure()
sns.displot(df["sepal_length"],kde=True)
plt.show()

# %% [markdown]
# # compare box plot of more than one data

# %%
plt.figure()
sns.boxplot(x="species",y="sepal_length",data=df)
plt.xticks(rotation=10,color="red")
plt.show()

# %% [markdown]
# # violen and swarm plot
# - advanced option of the ( boxplot )
# -  the width of a violin plot curve relates to the approximate frequency of data points in each region

# %%
plt.figure()
sns.violinplot(y=df["sepal_length"])
sns.swarmplot(y=df["sepal_length"],color="red")
plt.show()

# %%
plt.figure()
sns.violinplot(x="species",y=df["sepal_length"],data=df)
plt.show()

# %%
plt.figure()
sns.violinplot(x="species",y=df["sepal_length"],data=df)
sns.swarmplot(x="species",y=df["sepal_length"],color="red",data=df)
plt.show()

# %%
plt.figure()
sns.swarmplot(x="species",y=df["sepal_length"],color="red",data=df)
plt.show()

# %% [markdown]
# # heatmap()
# - it convert the pivot_table into graph
# ## df.corr()
# - show the relations between the variables
# - it uses colleration (df.corr( method= "pearson " )) is the defult method
# - pearson colleration coefficient is [-1,1]  ,
#     - = 0 ,  there is no relation
#     - +  , the ralation in positive
#     - - , the relation is negative
#     - +1 , perfect relation ... and so on

# %%
# import the data
df_shale=pd.read_csv("D:/Programming/DATA - SCIENCE/oil_data/Chapter 2/Data Import/Chapter2_Shale_Gas_Wells_DataSet.csv")

# %%
df_shale.corr()
# Out:
#                    Stage Spacing    bbl/ft  Well Spacing       Dip  Thickness  \
# Stage Spacing           1.000000 -0.201217     -0.385358 -0.056128  -0.422104
# bbl/ft                 -0.201217  1.000000      0.658193 -0.042710   0.516609
# Well Spacing           -0.385358  0.658193      1.000000 -0.100831   0.761738
# Dip                    -0.056128 -0.042710     -0.100831  1.000000  -0.090604
# Thickness              -0.422104  0.516609      0.761738 -0.090604   1.000000
# Lateral Length         -0.219911  0.311879      0.201688  0.091257   0.302391
# Injection Rate         -0.355152  0.572838      0.743285 -0.085775   0.733145
# Porosity               -0.396667  0.529269      0.699242 -0.063604   0.757434
# ISIP                   -0.626452  0.312047      0.492941  0.007361   0.612221
# Water Saturation        0.583152 -0.314534     -0.530765 -0.036001  -0.668960
# Percentage of LG        0.290471 -0.392546     -0.235675 -0.121290  -0.187009
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_shale.corr(),annot=True,cmap="coolwarm")
plt.show()

# %% [markdown]
# # clustermap()
# - i don't know what it means yet

# %%
df_pricing=pd.read_csv("D:/Programming/DATA - SCIENCE/oil_data/Chapter 2/Seaborn Plotting/Chapter2_Natural_Gas_Pricing_Version2_DataSet.csv")

# %%
df_pricing=df_pricing.loc[0:270]
df_new=df_pricing.pivot_table(index="Month",columns="Prior to 2000",values="Value",aggfunc="mean")
df_new
# Out:
# Prior to 2000       0.0       1.0
# Month
# April          3.453333  5.549500
# August         3.720000  5.451053
# December       3.383333  6.168421
# February       2.976667  5.760000
# January        3.803333  5.765000
# July           3.460000  5.427000
# June           3.610000  5.583500
# March          3.260000  5.533500
# May            3.466667  5.680000
# November       3.300000  6.138421
# October        4.140000  5.674737
# September      3.903333  5.609474

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_new,annot=True,cmap="coolwarm",linewidths=3,linecolor="white")
plt.show()

# %%
plt.figure()
sns.clustermap(df_new,cmap='coolwarm',standard_scale=1)
